# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
len(long_phrase)>len(short_phrase)
# Out:
# False

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
filebyte=float(input('введите размер файла '))
'%s %.2f%s' % ('Объем файла равен ', filebyte/(2**20),'Mb')
# Out:
# введите размер файла 3434343434
# 'Объем файла равен  3275.25Mb'

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
month=input('введите месяц: ')
day=int(input('введите число: '))
if ((month == 'март') and (21 <= day <= 31)) or ((month == 'апрель') and (1 <= day <= 20)): #21.03 - 20.04
    print('Овен')
elif ((month == 'апрель') and (21 <= day <= 30)) or ((month == 'май') and (1 <= day <= 20)): #21.04 - 20.05
    print('Телец')
elif ((month == 'май') and (21 <= day <= 31)) or ((month == 'июнь') and (1 <= day <= 20)): #21.05 - 20.06
    print('Близнецы')
elif ((month == 'июнь') and (21 <= day <= 30)) or ((month == 'июль') and (1 <= day <= 22)): #21.06 - 22.07
    print('Рак')
elif ((month == 'июль') and (23 <= day <= 31)) or ((month == 'август') and (1 <= day <= 22)): #23.07 - 22.08
    print('Лев')
elif ((month == 'август') and (23 <= day <= 31)) or ((month == 'сентябрь') and (1 <= day <= 23)): #23.08 - 23.09
    print('Дева')
elif ((month == 'сентябрь') and (24 <= day <= 30)) or ((month == 'октябрь') and (1 <= day <= 23)): #24.09 - 23.10
    print('Весы')
elif ((month == 'октябрь') and (24 <= day <= 31)) or ((month == 'ноябрь') and (1 <= day <= 21)): #24.10 - 21.11
    print('Скорпион')
elif ((month == 'ноябрь') and (22 <= day <= 30)) or ((month == 'декабрь') and (1 <= day <= 21)): #22.11 - 21.12
    print('Стрелец')
elif ((month == 'декабрь') and (22 <= day <= 31)) or ((month == 'январь') and (1 <= day <= 21)): #22.12 - 21.01
    print('Козерог')
elif ((month == 'январь') and (22 <= day <= 31)) or ((month == 'февраль') and (1 <= day <= 18)): #22.01 - 18.02
    print('Водолей')
elif ((month == 'февраль') and (19 <= day <= 29)) or ((month == 'март') and (1 <= day <= 20)): #19.02 - 20.03
    print('Рыбы')
else:
    print('не корректны введены данные')
# Out:
# введите месяц: март
# введите число: 33
# не корректны введены данные

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
try:
    salary=int(input('Введите заработанную плату в месяц: '))
    mortgage=int(input('Введите сколько процентов уходит на ипотеку: '))
    life=int(input('Введите сколько процентов уходит на "жизнь": '))
    award=int(input('Введите количество премий за год: '))
    print('На ипотеку было потрачено:', salary*(mortgage/100)*12 ,'рублей\n Было накоплено:',salary*12*((100-mortgage-life)/100)+award*salary/2,'рублей')
except Exception:
    print('не корректно внесена информация')
# Out:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 50
# Введите сколько процентов уходит на "жизнь": 80
# Введите количество премий за год: 1
# На ипотеку было потрачено: 600000.0 рублей
#  Было накоплено: -310000.0 рублей
